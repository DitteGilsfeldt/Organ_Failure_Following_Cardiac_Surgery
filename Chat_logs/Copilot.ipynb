# %% [markdown]
# # **URL af Bing Copilot samtaler**

# %% [markdown]
# ### 14.02.2024
# 14:30

# %% [markdown]
# https://www.bing.com/search?q=Bing+AI&showconv=1&FORM=hpcodx
# Dato: 14/02/24
# Klokkeslet: 14:30
#
#
#
# Hello, I have this project description: "Title: Organ failure following cardiac surgery – the use of AI for prediction modelling. Supervisors: Lars Grønlykke and Theis Skovgaard Itenov (Rigshospitalet), Morten Mørup Motivation A series of risk scores exist for cardiac surgery. The most widely used are The European System for Cardiac Operative Risk Evaluation (EuroSCORE 2) and The Society of Thoracic Surgeons (STS) Risk Score. Such risk scores are designed to give the best overall estimates of complication rates, but they lack precision in estimating the risk for the individual patient. Despite these shortcomings these risk scores are still used daily as clinical decision guidance, to provide information to the patient regarding the risk of surgery and to optimize resources in the intensive care unit after surgery. Another drawback to the current risk scores is that they are typically designed to predict mortality, but not morbidity. Project description Every year 1800 patients undergo cardiac surgery at Rigshospitalet. A significant part of these will experience complications that will keep them hospitalized for longer and potentially be fatal. In this project, we will investigate whether AI can be utilized to create more precise prediction models and if it is possible to detect complications earlier. This should ultimately lead to tools that can guide the clinicians, but also the patients when deciding on surgery. Another potential benefit is the better use of resources in the intensive care unit handling these patients postoperatively." And I would like to find some relevant key-search words for upcoming research of the project. Can you recommend some?
#
#
# Bing
# Sure, here are some key search terms that might be relevant to your project:
# 1.	Cardiac Surgery Complications
# 2.	Postoperative Organ Failure
# 3.	AI in Predictive Modelling
# 4.	Risk Scores in Cardiac Surgery
# 5.	EuroSCORE 2
# 6.	The Society of Thoracic Surgeons (STS) Risk Score
# 7.	Individual Patient Risk Estimation
# 8.	Morbidity Prediction Models
# 9.	Optimization of ICU Resources
# 10.	Early Detection of Surgical Complications
# 11.	AI in Clinical Decision Support
# These terms should help you find relevant literature and resources for your project. Remember to use different combinations of these terms to broaden your search. Good luck with your research! 📚

# %% [markdown]
# ### 14.02.2024
# 14:30

# %% [markdown]
# https://www.bing.com/search?q=Bing+AI&showconv=1&FORM=hpcodx
# Dato: 14/02/24
# Klokkeslet: 14:30
#
#
#
# Can you expand these keywords for searching?
# - Prediction model
# - Comblication rate, before surgery
# - Lack precision for estimate
# - Cardiac surgery
# - Training and AI model
# - Pytorch for AI
# - Generated AI
# - Logistisc regression
# - Baseline model
# - Neural Network
# - Group KNN
# - Classification
# - Feature selection
# - Statistic model for AI
# - Euro Score (Se vejleder møde 1, under baseline model)
#
# Bing
# Sure, here are some expanded versions of your keywords that might be useful for your research:
# 1.	Prediction Model in Healthcare
# 2.	Preoperative Complication Rate in Cardiac Surgery
# 3.	Precision of Risk Estimation Models
# 4.	Outcomes and Complications in Cardiac Surgery
# 5.	Training AI Models for Predictive Healthcare
# 6.	Using PyTorch for Predictive Modelling in Healthcare
# 7.	AI-Generated Predictive Models in Medicine
# 8.	Logistic Regression in Medical Risk Prediction
# 9.	Baseline Models in Predictive Healthcare
# 10.	Neural Network Applications in Predictive Healthcare
# 11.	Group KNN Classification in Medical Data Analysis
# 12.	Feature Selection Techniques in Machine Learning for Healthcare
# 13.	Statistical Models for AI in Healthcare
# 14.	EuroSCORE as a Baseline Model in Cardiac Surgery Risk Prediction
# Remember to use different combinations of these terms to broaden your search. Good luck with your research! 📚

# %% [markdown]
# # 10/04/2024

# %% [markdown]
# r
# im trying to open a csv file from a NTFS remote directory using pandas in python.
#
# lll = pd.read_csv("//L/.../.../
#
# but this returns: Path not found in directory
#
# When opening a CSV file using **pandas** in Python, it's essential to handle the file path correctly, especially when dealing with remote directories. Let's explore a couple of approaches to achieve this:
#
# 1. **Relative Path**:
#    - If your script is located in the `scripts_folder`, and the CSV file you want to read is in the `data_folder`, you can use a relative path.
#    - Assuming your directory structure is as follows:
#      ```
#      folder/
#      ├── folder2/
#      │   ├── scripts_folder/
#      │   │   └── script.py
#      │   └── data_folder/
#      │       └── data.csv
#      ```
#    - You can read the CSV file like this:
#      ```python
#      import pandas as pd
#      lll = pd.read_csv("../data_folder/data.csv")
#      ```
#    - The `..` notation moves up one level in the directory hierarchy, allowing you to access the `data_folder`.
#
# 2. **Absolute Path**:
#    - If you prefer an absolute path, you can construct it using the `os` module.
#    - For example:
#      ```python
#      import os
#      import pandas as pd
#
#      # Get the absolute path to the directory containing the script
#      script_directory = os.path.dirname(__file__)
#
#      # Construct the absolute path to the CSV file
#      csv_file_path = os.path.join(script_directory, "../data_folder/data.csv")
#
#      # Read the CSV file
#      lll = pd.read_csv(csv_file_path)
#      ```
#    - Replace `"../data_folder/data.csv"` with the actual relative path to your CSV file.
#
# Remember to adjust the paths based on your specific directory structure. If you encounter any issues, ensure that the file exists at the specified location and that you have the necessary permissions to access it. 🐍📊
#
# Source: Conversation with Bing, 4/10/2024
# (1) python - How to open my files in data_folder with pandas using relative .... https://stackoverflow.com/questions/35384358/how-to-open-my-files-in-data-folder-with-pandas-using-relative-path.
# (2) python - Opening a csv file with pandas with relative path from another .... https://stackoverflow.com/questions/72084549/opening-a-csv-file-with-pandas-with-relative-path-from-another-main-file-in-anot.
# (3) Pandas read_csv () – Read CSV and Delimited Files in Pandas. https://datagy.io/pandas-read_csv/.
#
# the problem is that the csv files are in a seperate remote directory while the python script is on the local C drive.
#
# I understand! When dealing with CSV files located in a separate remote directory while your Python script resides on the local C drive, you'll need to handle the file paths appropriately. Let's explore a solution for reading the remote CSV file using **pandas**:
#
# 1. **Relative Path**:
#    - If your Python script is on the local C drive and the CSV file is in a remote directory, you can use a relative path.
#    - Assuming your directory structure is as follows:
#      ```
#      local_c_drive/
#      ├── scripts_folder/
#      │   └── script.py
#      └── remote_directory/
#          └── data.csv
#      ```
#    - You can read the CSV file like this:
#      ```python
#      import pandas as pd
#      lll = pd.read_csv("../remote_directory/data.csv")
#      ```
#    - The `..` notation moves up one level in the directory hierarchy, allowing you to access the `data.csv` file in the remote directory.
#
# 2. **Absolute Path**:
#    - To construct an absolute path, you can use the `os` module.
#    - For example:
#      ```python
#      import os
#      import pandas as pd
#
#      # Specify the absolute path to the remote CSV file
#      remote_csv_path = "//L/.../.../data.csv"
#
#      # Read the CSV file
#      lll = pd.read_csv(remote_csv_path)
#      ```
#    - Replace `//L/.../.../data.csv` with the actual path to your remote CSV file.
#
# Remember to adjust the paths based on your specific setup. Ensure that the remote CSV file exists and that you have the necessary permissions to access it. 🐍📊
#
# Source: Conversation with Bing, 4/10/2024
# (1) python - How to open my files in data_folder with pandas using relative .... https://stackoverflow.com/questions/35384358/how-to-open-my-files-in-data-folder-with-pandas-using-relative-path.
# (2) python - Opening a csv file with pandas with relative path from another .... https://stackoverflow.com/questions/72084549/opening-a-csv-file-with-pandas-with-relative-path-from-another-main-file-in-anot.
# (3) Pandas read_csv () – Read CSV and Delimited Files in Pandas. https://datagy.io/pandas-read_csv/.
#
# im working with a total of 15 csv files. All these files has an id number that connects all the data. How should i go about handling this data?
#
# Handling multiple CSV files with a common ID number can be done effectively using **pandas**. Let's break down the steps to manage your data:
#
# 1. **Load the CSV Files**:
#    - Read each of your 15 CSV files into separate pandas DataFrames. You can use the `pd.read_csv()` function for this.
#    - For example:
#      ```python
#      import pandas as pd
#
#      # Read CSV files (adjust file paths accordingly)
#      df1 = pd.read_csv("file1.csv")
#      df2 = pd.read_csv("file2.csv")
#      # ... (repeat for other files)
#      ```
#
# 2. **Data Exploration and Cleaning**:
#    - Inspect the data in each DataFrame to understand its structure, column names, and any missing values.
#    - Perform any necessary data cleaning, such as handling missing values, removing duplicates, or converting data types.
#
# 3. **Merge DataFrames**:
#    - Since all your CSV files share a common ID number, you can merge them based on this ID.
#    - Use the `pd.merge()` function to combine DataFrames. Specify the common column (ID) as the key for merging.
#    - Example:
#      ```python
#      # Merge two DataFrames based on the 'id' column
#      merged_df = pd.merge(df1, df2, on='id', how='inner')
#      ```
#
# 4. **Repeat for All Files**:
#    - Repeat the merging process for all 15 DataFrames. You can create a loop or use a list of DataFrames to simplify the process.
#    - Adjust the merge strategy (`how`) based on your requirements (inner, outer, left, or right join).
#
# 5. **Data Analysis and Visualization**:
#    - Once you have a single DataFrame containing data from all files, you can perform various analyses, aggregations, and visualizations.
#    - Explore relationships between columns, calculate summary statistics, and create plots.
#
# 6. **Save the Merged Data**:
#    - If needed, save the merged DataFrame to a new CSV file for further analysis or sharing.
#    - Example:
#      ```python
#      merged_df.to_csv("combined_data.csv", index=False)
#      ```
#
# Remember to adapt the code snippets above to your specific file paths, column names, and data requirements. With pandas, you can efficiently manage and analyze your data across multiple CSV files. 🐍📊
#
# Source: Conversation with Bing, 4/10/2024
# (1) undefined. https://stackoverflow.com/questions/35384358/how-to-open-my-files-in-data-folder-with-pandas-using-relative-path.
# (2) undefined. https://stackoverflow.com/questions/72084549/opening-a-csv-file-with-pandas-with-relative-path-from-another-main-file-in-anot.
# (3) undefined. https://datagy.io/pandas-read_csv/.
