# %% [markdown]
# **Hvilke søgeord / termer kunne være relevante for jeres projekt?**
# - Lav en brutto-Liste
# - Mindst 7

# %% [markdown]
# **List of search words**
# - Prediction model
# - Comblication rate, before surgery
# - Lack precision for estimate
# - Cardiac surgery
# - Training and AI model
# - Pytorch for AI
# - Generated AI
# - Logistisc regression
# - Baseline model
# - Neural Network
# - Group KNN - Classification
# - Feature selection
# - Statistic model for AI
# - Euro Score (Se vejleder møde 1, under baseline model)

# %% [markdown]
# **I skal nu udfordre de søgeord, som I lavede tidligere - ved at 'udspørge både Bing Chat / Copolit (via EDGE) og ChatGPT på jeres emne(r)**

# %% [markdown]
# **Overvej også hvordan I vil udforme en søgeprofil til senere brug (i evt. DTU Findit, Google Scholar eller Scopus)**

# %% [markdown]
# **HUSK at dokumentere / gemme jeres PROMPTs og evt. resultater**

# %% [markdown]
# **Chat**
#
# Hello, I have this project description:
#
# "Title: Organ failure following cardiac surgery – the use of AI for prediction modelling. Supervisors: Lars Grønlykke and Theis Skovgaard Itenov (Rigshospitalet), Morten Mørup Motivation
# A series of risk scores exist for cardiac surgery. The most widely used are The European System for Cardiac Operative Risk Evaluation (EuroSCORE 2) and The Society of Thoracic Surgeons (STS) Risk Score. Such risk scores are designed to give the best overall estimates of complication rates, but they lack precision in estimating the risk for the individual patient. Despite these shortcomings these risk scores are still used daily as clinical decision guidance, to provide information to the patient regarding the risk of surgery and to optimize resources in the intensive care unit after surgery. Another drawback to the current risk scores is that they are typically designed to predict mortality, but not morbidity.
# Project description
# Every year 1800 patients undergo cardiac surgery at Rigshospitalet. A significant part of these will experience complications that will keep them hospitalized for longer and potentially be fatal. In this project, we will investigate whether AI can be utilized to create more precise prediction models and if it is possible to detect complications earlier. This should ultimately lead to tools that can guide the clinicians, but also the patients when deciding on surgery. Another potential benefit is the better use of resources in the intensive care unit handling these patients postoperatively."
#
# And I would like to find some relevant key-search words for upcoming research of the project. Can you recommend some?
#
# Svar:
#
#
# Certainly! Crafting a list of key search terms will help you navigate through a vast amount of literature efficiently. For your project on using AI for prediction modeling in the context of organ failure following cardiac surgery, consider these search terms and phrases:
#
# Cardiac Surgery Complications - To find studies or data on common postoperative complications.
# AI in Healthcare - Broad term to find applications of AI within the healthcare sector.
# Machine Learning Models in Medicine - More specific to the application of machine learning techniques in medical diagnosis and prognosis.
# Predictive Analytics in Cardiology - To find research related to predictive analytics specifically in the field of cardiology.
# Postoperative Care Optimization - To explore strategies and technologies used in improving post-surgical care.
# EuroSCORE 2 - For literature on the most widely used cardiac surgery risk score.
# STS Risk Score - To find information on the Society of Thoracic Surgeons' approach to assessing surgical risk.
# Patient-specific Risk Assessment - For studies on individualized risk assessment methods.
# Early Detection of Cardiac Surgery Complications - To identify methods for early complication detection.
# Deep Learning in Clinical Decision Support - Specifically looking at deep learning applications in supporting clinical decisions.
# Intensive Care Unit Resource Optimization - For strategies on ICU resource management, particularly after cardiac surgery.
# Outcome Prediction in Cardiac Surgery - To find studies focusing on predicting surgical outcomes.
# Hospital Readmission after Cardiac Surgery - To identify factors and models predicting hospital readmissions.
# Data Mining in Health Records - For methodologies on extracting useful information from electronic health records for predictive modeling.
# Morbidity Prediction Models - Since the project focuses on predicting morbidity rather than mortality.
# These terms can be combined or adjusted based on the specific focus at different stages of your project. For example, combining "AI in Healthcare" with "Predictive Analytics in Cardiology" might narrow down search results to AI applications in cardiac risk assessment. Similarly, integrating "Deep Learning" with "Outcome Prediction in Cardiac Surgery" could help find cutting-edge research on using deep learning models for post-surgery outcomes.
#
#
#
# Can you expand these keywords for searching?
#
# Prediction model
# Comblication rate, before surgery
# Lack precision for estimate
# Cardiac surgery
# Training and AI model
# Pytorch for AI
# Generated AI
# Logistisc regression
# Baseline model
# Neural Network
# Group KNN - Classification
# Feature selection
# Statistic model for AI
# Euro Score (Se vejleder møde 1, under baseline model)
#
# Svar:
# Expanding these keywords into more detailed search queries can enhance the specificity and relevance of your search results. Here are expanded versions of the keywords you provided, aimed at improving search effectiveness for your project on using AI for prediction modeling in organ failure following cardiac surgery:
#
# "Prediction Model for Cardiac Surgery Outcomes" - To find studies on models specifically designed to predict outcomes of cardiac surgeries.
#
# "Preoperative Complication Rate Prediction in Cardiac Surgery" - For research focused on predicting complications before cardiac surgery.
#
# "Accuracy and Limitations of Risk Estimation in Cardiac Surgery" - To explore studies discussing the precision issues of current risk estimation methods.
#
# "Advanced Analytics in Cardiac Surgery Patient Care" - For comprehensive insights into how data analytics is applied to cardiac surgery.
#
# "Training AI Models for Healthcare Applications" - Focused on methodologies for training AI models in the healthcare domain.
#
# "Using PyTorch for Healthcare AI Development" - To find resources and case studies on developing AI models with PyTorch in healthcare.
#
# "Generation of AI Models for Medical Diagnosis and Prognosis" - For information on the process of generating AI models aimed at diagnosis and prognosis in medicine.
#
# "Logistic Regression in Medical Outcome Prediction" - To identify studies using logistic regression for predicting medical outcomes.
#
# "Baseline Models in Cardiac Surgery Risk Assessment" - Focused on the initial models used for risk assessment in cardiac surgery, including the EuroSCORE.
#
# "Neural Network Applications in Predicting Surgical Outcomes" - For research on the use of neural networks to predict outcomes in surgery.
#
# "Group KNN Classification for Patient Risk Stratification" - To explore the use of Group K-Nearest Neighbors in classifying patients based on risk levels.
#
# "Feature Selection Techniques in Medical Prediction Models" - For studies on selecting the most relevant features in datasets for medical prediction.
#
# "Statistical Models vs AI in Predicting Health Outcomes" - To compare traditional statistical models with AI approaches in health outcome prediction.
#
# "Evaluation and Comparison of EuroSCORE with AI-based Models" - Looking for research that evaluates the EuroSCORE against newly developed AI models for accuracy and reliability.
#
# By using these expanded search terms, you can dive deeper into specific areas of interest within your project, ensuring that you gather a wide range of relevant and detailed information. These queries can be adjusted as needed to fit the exact focus of your research at different stages.
#
# https://chat.openai.com/share/87b739d7-bf52-43cd-9734-6c270c32061b

# %% [markdown]
# **CoPolit**
#
# Hello, I have this project description:
#
# "Title: Organ failure following cardiac surgery – the use of AI for prediction modelling. Supervisors: Lars Grønlykke and Theis Skovgaard Itenov (Rigshospitalet), Morten Mørup Motivation
# A series of risk scores exist for cardiac surgery. The most widely used are The European System for Cardiac Operative Risk Evaluation (EuroSCORE 2) and The Society of Thoracic Surgeons (STS) Risk Score. Such risk scores are designed to give the best overall estimates of complication rates, but they lack precision in estimating the risk for the individual patient. Despite these shortcomings these risk scores are still used daily as clinical decision guidance, to provide information to the patient regarding the risk of surgery and to optimize resources in the intensive care unit after surgery. Another drawback to the current risk scores is that they are typically designed to predict mortality, but not morbidity.
# Project description
# Every year 1800 patients undergo cardiac surgery at Rigshospitalet. A significant part of these will experience complications that will keep them hospitalized for longer and potentially be fatal. In this project, we will investigate whether AI can be utilized to create more precise prediction models and if it is possible to detect complications earlier. This should ultimately lead to tools that can guide the clinicians, but also the patients when deciding on surgery. Another potential benefit is the better use of resources in the intensive care unit handling these patients postoperatively."
#
# And I would like to find some relevant key-search words for upcoming research of the project. Can you recommend some?
#
#
# Sure, here are some key search terms that might be relevant to your project:
#
# 1. **Cardiac Surgery Complications**
# 2. **Postoperative Organ Failure**
# 3. **AI in Predictive Modelling**
# 4. **Risk Scores in Cardiac Surgery**
# 5. **EuroSCORE 2**
# 6. **The Society of Thoracic Surgeons (STS) Risk Score**
# 7. **Individual Patient Risk Estimation**
# 8. **Morbidity Prediction Models**
# 9. **Optimization of ICU Resources**
# 10. **Early Detection of Surgical Complications**
# 11. **AI in Clinical Decision Support**
#
# These terms should help you find relevant literature and resources for your project. Remember to use different combinations of these terms to broaden your search. Good luck with your research! 📚
#
# Can you expand these keywords for searching?
#
# - Prediction model
# - Comblication rate, before surgery
# - Lack precision for estimate
# - Cardiac surgery
# - Training and AI model
# - Pytorch for AI
# - Generated AI
# - Logistisc regression
# - Baseline model
# - Neural Network
# - Group KNN - Classification
# - Feature selection
# - Statistic model for AI
# - Euro Score (Se vejleder møde 1, under baseline model)
#
# Sure, here are some expanded versions of your keywords that might be useful for your research:
#
# 1. **Prediction Model in Healthcare**
# 2. **Preoperative Complication Rate in Cardiac Surgery**
# 3. **Precision of Risk Estimation Models**
# 4. **Outcomes and Complications in Cardiac Surgery**
# 5. **Training AI Models for Predictive Healthcare**
# 6. **Using PyTorch for Predictive Modelling in Healthcare**
# 7. **AI-Generated Predictive Models in Medicine**
# 8. **Logistic Regression in Medical Risk Prediction**
# 9. **Baseline Models in Predictive Healthcare**
# 10. **Neural Network Applications in Predictive Healthcare**
# 11. **Group KNN Classification in Medical Data Analysis**
# 12. **Feature Selection Techniques in Machine Learning for Healthcare**
# 13. **Statistical Models for AI in Healthcare**
# 14. **EuroSCORE as a Baseline Model in Cardiac Surgery Risk Prediction**
#
# Remember to use different combinations of these terms to broaden your search. Good luck with your research! 📚
#
# - https://www.bing.com/search?q=Bing+AI&showconv=1&FORM=hpcodx
